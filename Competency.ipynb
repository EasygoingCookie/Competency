# %% [markdown]
# ### Влияние личных качеств на KPI

# %% [markdown]
# #### Индивидуальная интерпретация тестируемого объекта

# %%
rid, pid = (0, 3)
pred_label = xgb_clf.predict(test[[pid],:])[0]
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[rid], test[pid], feature_names=feature_names)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# #### Графики Shapley values на датасете

# %%
shap.initjs()

exp_array =  shap.sample(test, 100)
shap_values = explainer.shap_values(exp_array)
shap.force_plot(explainer.expected_value, shap_values, exp_array, feature_names=feature_names)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# #### Влияние и важность признаков

# %%
shap_values = explainer.shap_values(train)
shap.summary_plot(shap_values, train, feature_names)

# %% [markdown]
# ### Влияние управленческих качеств на KPI

# %%
shap_values = explainer.shap_values(train)
shap.summary_plot(shap_values, train, feature_names)

# %%
shap.initjs()

exp_array =  shap.sample(train, 50)
shap_values = explainer.shap_values(exp_array)
shap.force_plot(explainer.expected_value, shap_values, exp_array, feature_names=feature_names)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
shap_values = explainer.shap_values(test[[1],:])
rid, pid = (0, 1)
pred_label = xgb_clf.predict(test[[pid],:])[0]
#print("True class {0:d}, predicted one is {1:d} (with P = {2:.2f})".format(labels_test[pid], 
#      pred_label, xgb_clf.predict_proba(test[[pid],:])[0][pred_label]))
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[rid], test[pid], feature_names=feature_names)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# ### Влияние КМ на KPI

# %%
shap_values = explainer.shap_values(train)
shap.summary_plot(shap_values, train, feature_names)

# %% [markdown]
# ## Куда двигаться дальше?

# %% [markdown]
# #### Улучшенная предобработка признаков
#
# a) удаление незначительных kpi
#
# b) возможно, поможет нормировка
#
# c) более разумное заполнение пустых значений
#
# d) детальная проработка управленческих kpi
#
# #### Более продуманное выделение таргетов
#
# a) возможно, есть смысл выделять те объекты, для которых таргеты "сильно" больше 1 или "сильно" меньше 0 и строить модели для них.
#
# b) в таком случае, классы могут стать несбалансированными - замена метрики на f-score
#
# #### Построение модели
#
# a) валидация
#
# b) тюнинг гиперпараметров модели (поиск по сетке)
#
# c) проверка на устойчивость
#
# d) сужение поля признаков с учетом первого приближения
#
# e) построение модели на всем признаковом поле (на трех датасетах)
#
# f) построение лучшей и устойчивой модели в купе с признаком "Стаж"
#
# g) возможно, добавление некоторых других признаков (пол, возраст и т.д.)
#
# h) добавление других пулов компетенций
#
#
# #### Поиск зависимостей от продукта (группы, функции)
#
# a) ответить на вопрос: образовываются ли кластеры похожих объектов, в зависимости от продукта/группы/функции
#
# b) схожи ли зависимости kpi от компетенций на обособленном продукте (обучить модель на всем, кроме HHI, посчитать метрику на HHI)
